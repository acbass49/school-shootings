# %% [markdown]
# ## Basic Bayesian Poisson Regression and Prediction
# ### Alex Bass

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc3 as pm
import seaborn as sns
import os
import bambi as bmb

from formulae import design_matrices

# %%
data = pd.read_csv('/Users/alex/Library/CloudStorage/OneDrive-Personal/DS6040/Project - School Shootings/Finalized_Data/train.csv') #reading in final data
data.columns
# Out:
# Index(['STATE', 'gun_own', 'hunt_license', 'background_checks',
#        'gun_permit_law', 'under40', 'Male', 'White', 'Black', 'Asian',
#        'Hispanic', 'Unemployment_rate_2021', 'Median_Household_Income_2020',
#        'ba_plus', 'less_than_hs', 'hs', 'some_col', 'urban_rural',
#        'population', 'n', 'gun_strictness'],
#       dtype='object')

# %%
data.dropna(inplace = True) #dropping NAs

# %%
#scaling all data
columns_to_scale = ['gun_own',
       'gun_permit_law', 'under40', 'Male', 'White', 'Black', 'Asian',
       'Hispanic', 'Unemployment_rate_2021', 'Median_Household_Income_2020',
       'ba_plus', 'less_than_hs', 'hs', 'some_col',
       'population', 'n', 'gun_strictness']

data[columns_to_scale] = data[columns_to_scale].apply(lambda x : (x - np.mean(x))/np.std(x))

# %%
fml = "n ~ gun_own + hunt_license + background_checks + gun_permit_law + under40 + Male + White + Black + Asian + Hispanic + Unemployment_rate_2021 + Median_Household_Income_2020 + ba_plus + less_than_hs + hs + some_col + urban_rural + population + gun_strictness"  # full formulae formulation

dm = design_matrices(fml, data, na_action="error")

mx_ex = dm.common.as_dataframe()
mx_en = dm.response.as_dataframe()

mx_ex
# Out:
#       Intercept   gun_own  hunt_license  background_checks  gun_permit_law  \
# 0           1.0  0.833042      0.341758                0.0       -0.522691
# 1           1.0  0.833042      0.341758                0.0       -0.522691
# 2           1.0  0.833042      0.341758                0.0       -0.522691
# 3           1.0  0.833042      0.341758                0.0       -0.522691
# 4           1.0  0.833042      0.341758                0.0       -0.522691
# ...         ...       ...           ...                ...             ...
# 3136        1.0  2.206241      0.538439                0.0       -0.522691
# 3137        1.0  2.206241      0.538439                0.0       -0.522691
# 3138        1.0  2.206241      0.538439                0.0       -0.522691
# 3139        1.0  2.206241      0.538439                0.0       -0.522691
# 3140        1.0  2.206241      0.538439                0.0       -0.522691
#
#        under40      Male     White     Black     Asian  Hispanic  \
# ...

# %%
quick_prior_change = 10

with pm.Model() as mdl_fish:

    # define priors, weakly informative Normal
    b0 = pm.Normal("Intercept", mu=0, sigma=quick_prior_change)
    b2 = pm.Normal("background_checks", mu=0, sigma=quick_prior_change)
    b3 = pm.Normal("gun_permit_law", mu=0, sigma=quick_prior_change)
    b4 = pm.Normal("under40", mu=0, sigma=quick_prior_change)
    b5 = pm.Normal("Male", mu=0, sigma=quick_prior_change)
    b6 = pm.Normal("White", mu=0, sigma=quick_prior_change)
    b7 = pm.Normal("Black", mu=0, sigma=quick_prior_change)
    b8 = pm.Normal("Asian", mu=0, sigma=quick_prior_change)
    b9 = pm.Normal("Hispanic", mu=0, sigma=quick_prior_change)
    b10 = pm.Normal("Unemployment_rate_2021", mu=0, sigma=quick_prior_change)
    b11 = pm.Normal("Median_Household_Income_2020", mu=0, sigma=quick_prior_change)
    b12 = pm.Normal("ba_plus", mu=0, sigma=quick_prior_change)
    b13 = pm.Normal("less_than_hs", mu=0, sigma=quick_prior_change)
    b14 = pm.Normal("hs", mu=0, sigma=quick_prior_change)
    b15 = pm.Normal("some_col", mu=0, sigma=quick_prior_change)
    b16 = pm.Normal("urban_rural", mu=0, sigma=quick_prior_change)
    b17 = pm.Normal("population", mu=0, sigma=quick_prior_change)
    b18 = pm.Normal("gun_strictness", mu=0, sigma=quick_prior_change)

    # define linear model and exp link function
    theta = (
        b0
        + b2 * mx_ex["background_checks"].values
        + b3 * mx_ex["gun_permit_law"].values
        + b4 * mx_ex["under40"].values
        + b5 * mx_ex["Male"].values
        + b6 * mx_ex["White"].values
        + b7 * mx_ex["Black"].values
        + b8 * mx_ex["Asian"].values
        + b9 * mx_ex["Hispanic"].values
        + b10 * mx_ex["Unemployment_rate_2021"].values
        + b11 * mx_ex["Median_Household_Income_2020"].values
        + b12 * mx_ex["ba_plus"].values
        + b13 * mx_ex["less_than_hs"].values
        + b14 * mx_ex["hs"].values
        + b15 * mx_ex["some_col"].values
        + b16 * mx_ex["urban_rural"].values
        + b17 * mx_ex["population"].values
        + b18 * mx_ex["gun_strictness"].values
    )

    ## Define Poisson likelihood
    y = pm.Poisson("y", mu=pm.math.exp(theta), observed=mx_en["n"].values)

# %%
with mdl_fish:
    inf_fish = pm.sample(500, tune=1000, cores=4, return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [gun_strictness, population, urban_rural, some_col, hs, less_than_hs, ba_plus, Median_Household_Income_2020, Unemployment_rate_2021, Hispanic, Asian, Black, White, Male, under40, gun_permit_law, background_checks, Intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 05:05<00:00 Sampling 4 chains, 227 divergences]
#     </div>
# ...

# %%
az.plot_trace(inf_fish);

# %%
model = bmb.Model(fml, data, family="poisson")

# %%
inf_fish_alt = model.fit(draws=2000, tune=2000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Intercept, gun_own, hunt_license, background_checks, gun_permit_law, under40, Male, White, Black, Asian, Hispanic, Unemployment_rate_2021, Median_Household_Income_2020, ba_plus, less_than_hs, hs, some_col, urban_rural, population, gun_strictness]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='552' class='' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
# ...

# %%
az.summary(inf_fish_alt)
# Out:
#                                 mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# Intercept                    -13.026  2.446 -18.159   -9.088      0.085
# gun_own                        0.602  0.107   0.396    0.804      0.003
# hunt_license                  -1.782  0.715  -3.166   -0.488      0.017
# background_checks              0.718  0.181   0.391    1.069      0.004
# gun_permit_law                -0.264  0.088  -0.437   -0.104      0.002
# under40                        0.369  0.096   0.187    0.549      0.002
# Male                          -0.559  0.175  -0.894   -0.247      0.004
# White                          0.388  0.395  -0.307    1.140      0.011
# Black                          1.070  0.348   0.420    1.707      0.010
# Asian                          0.247  0.099   0.065    0.431      0.003
# Hispanic                       0.876  0.098   0.685    1.054      0.002
# Unemployment_rate_2021        -0.009  0.102  -0.206    0.180      0.003
# ...

# %%
az.plot_forest(
    inf_fish_alt,
    combined=True,
    figsize=(8, 4)
);

# %%
az.plot_trace(inf_fish_alt);

# %%
az.summary(np.exp(inf_fish_alt.posterior), kind="stats")
# Out:
#                                  mean        sd  hdi_3%   hdi_97%
# Intercept                       0.000     0.000   0.000     0.000
# gun_own                         1.836     0.197   1.450     2.189
# hunt_license                    0.216     0.170   0.023     0.521
# background_checks               2.084     0.382   1.426     2.825
# gun_permit_law                  0.771     0.068   0.645     0.900
# under40                         1.453     0.140   1.202     1.727
# Male                            0.580     0.101   0.401     0.768
# White                           1.599     0.704   0.645     2.879
# Black                           3.104     1.171   1.434     5.310
# Asian                           1.287     0.130   1.062     1.532
# Hispanic                        2.413     0.238   1.978     2.862
# Unemployment_rate_2021          0.996     0.102   0.809     1.192
# Median_Household_Income_2020    0.760     0.069   0.630     0.888
# ...

# %%
model.posterior_predictive(inf_fish_alt, draws=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3n/g1rn_qsj40dd1cm5v67yyt100000gn/T/ipykernel_5390/3897351760.py in <module>
# ----> 1 model.posterior_predictive(inf_fish_alt, draws=None)
#
# AttributeError: 'Model' object has no attribute 'posterior_predictive'

# %%
az.plot_ppc(inf_fish_alt, num_pp_samples=200);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3n/g1rn_qsj40dd1cm5v67yyt100000gn/T/ipykernel_5390/807651413.py in <module>
# ----> 1 az.plot_ppc(inf_fish_alt, num_pp_samples=200);
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/arviz/plots/ppcplot.py in plot_ppc(data, kind, alpha, mean, observed, color, colors, grid, figsize, textsize, data_pairs, var_names, filter_vars, coords, flatten, flatten_pp, num_pp_samples, random_seed, jitter, animated, animation_kwargs, legend, labeller, ax, backend, backend_kwargs, group, show)
#     220     for groups in (f"{group}_predictive", "observed_data"):
#     221         if not hasattr(data, groups):
# --> 222             raise TypeError(f'`data` argument must have the group "{groups}" for ppcplot')
#     223
#     224     if kind.lower() not in ("kde", "cumulative", "scatter"):
#
# ...

# %%
model.graph()

# %%
model.plot_priors()
# Out:
# array([[<AxesSubplot:title={'center':'Unemployment_rate_2021'}>,
#         <AxesSubplot:title={'center':'Intercept'}>,
#         <AxesSubplot:title={'center':'gun_permit_law'}>,
#         <AxesSubplot:title={'center':'gun_strictness'}>],
#        [<AxesSubplot:title={'center':'under40'}>,
#         <AxesSubplot:title={'center':'urban_rural'}>,
#         <AxesSubplot:title={'center':'Male'}>,
#         <AxesSubplot:title={'center':'hunt_license'}>],
#        [<AxesSubplot:title={'center':'Median_Household_Income_2020'}>,
#         <AxesSubplot:title={'center':'ba_plus'}>,
#         <AxesSubplot:title={'center':'gun_own'}>,
#         <AxesSubplot:title={'center':'White'}>],
#        [<AxesSubplot:title={'center':'population'}>,
#         <AxesSubplot:title={'center':'less_than_hs'}>,
#         <AxesSubplot:title={'center':'Black'}>,
#         <AxesSubplot:title={'center':'background_checks'}>],
#        [<AxesSubplot:title={'center':'Asian'}>,
# ...
